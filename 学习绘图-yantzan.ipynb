# %%
import matplotlib.pyplot as plt
import numpy as np

color = ['r','k','b','y','g']

x = np.linspace(0,15,100)

for i in range(0,5):
    if i % 2 ==0:
        y = np.sin(x) + i
    else:
        y = np.cos(x) + i
    plt.plot(x,y,color = color[i])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

color = ['r','k','b','y','g']

for i in range(0,5):
    x = np.linspace(i,15,100)
    if i % 2 ==0:
        y = np.sin(x) + i
    else:
        y = np.cos(x) + i
    plt.plot(x,y,color = color[i])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

A = np.random.standard_normal((100,2))
A1 = A - np.array((1,1))
A2 = A + np.array((1,1))
plt.scatter(A1[:,0],A1[:,1],color = '0.1',facecolor = 'r')
plt.scatter(A2[:,0],A2[:,1],color = '0.9',edgecolor = 'g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,10,0.1)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sqrt(x)

plt.plot(x,y1,color = 'r',ls = '-')
plt.plot(x,y2,color = 'g',ls = '--')
plt.plot(x,y3,color = 'y',ls = ':')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

A = np.random.rand(8)
B = np.random.rand(8)
x = np.arange(0,8)
plt.bar(x,A, color = 'g', hatch = 'x')
plt.bar(x,B, color = 'c', hatch = '/')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-6,6,1024)
y = np.sinc(x)

plt.plot(x,y,
        linewidth = 2,
        color = 'g',
        markevery = 32,
        marker = 'o',
        markersize = 8,
        markeredgewidth = 1.5,
        markerfacecolor = 'r',
        markeredgecolor = 'c'     
        )
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-4,4,1024)
y = 0.25 * (x + 4) * (x-2) *(x+1)
plt.plot(x,y)
plt.title('Relationship between speed and force')
plt.xlabel('Air speed [m/s]')
plt.ylabel('Force [N]')
box = {
    'facecolor': 'y',
    'edgecolor' : 'r',
    'boxstyle' : 'round'
}
plt.text(0.5,0, 'Minimum', bbox = box)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-4,4,1024)
y = 0.25 * (x + 4) * (x-2) *(x+1)
plt.plot(x,y)
plt.title('Relationship between speed and force')
plt.xlabel('Air speed [m/s]')
plt.ylabel('Force [N]')
dict = {
    'facecolor': 'y',
    'shrink' : 0.01,
    'width' : 0.5,
    'headwidth': 2
}
plt.annotate( 'Minimum', xy = (1,-2), xytext = (-1,1),arrowprops = dict)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,1000)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y1, ls = '--', label = 'sin(x)')
plt.plot(x,y2, c = 'g', ls = '-', label = 'cos(x)')
plt.legend()
plt.grid(True, lw = 0.5, ls = '--', color = '0')
plt.show()
