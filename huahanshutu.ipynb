# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

t = np.arange(10,90,5)
pi = np.pi

y1 = 18*(57.5+61.15*np.cos(2*t*pi/180)+13.98*np.cos(4*t*pi/180))/(16.57-13.98*np.cos(4*t*pi/180))
y2 = 20*(57.5+61.15*np.cos(2*t*pi/180)+13.98*np.cos(4*t*pi/180))/(16.57-13.98*np.cos(4*t*pi/180))
y3 = 22*(57.5+61.15*np.cos(2*t*pi/180)+13.98*np.cos(4*t*pi/180))/(16.57-13.98*np.cos(4*t*pi/180))
y4 = 24*(57.5+61.15*np.cos(2*t*pi/180)+13.98*np.cos(4*t*pi/180))/(16.57-13.98*np.cos(4*t*pi/180))
y5 = 26*(57.5+61.15*np.cos(2*t*pi/180)+13.98*np.cos(4*t*pi/180))/(16.57-13.98*np.cos(4*t*pi/180))
y6 = 28*(57.5+61.15*np.cos(2*t*pi/180)+13.98*np.cos(4*t*pi/180))/(16.57-13.98*np.cos(4*t*pi/180))
#y7 = 28*(57.5+61.15*np.cos(2*x)+13.98*np.cos(4*x))/(16.57-13.98*np.cos(4*x))

A, = plt.plot(t,y1,c = 'lightseagreen', ls = '--',lw = 2,label = 'R = 18mm')
B, = plt.plot(t,y2,c = 'orangered', ls = '-',lw = 2,label = 'R = 20mm')
C, = plt.plot(t,y3,c = 'blue', ls = '-.',lw = 2,label = 'R = 22mm')
D, = plt.plot(t,y4,c = 'darkgreen', ls = '-',lw = 2,label = 'R = 24mm')
E, = plt.plot(t,y5,c = 'dodgerblue', ls = ':',lw = 2,label = 'R = 26mm')
F, = plt.plot(t,y6,c = 'crimson', ls = '--',lw = 2,label = 'R = 28mm')
# G, = plt.scatter(x,y7,c='orangered', s=50,marker='*', alpha=1, label = 'Minima')

font1 = {'family' : 'arial',
'weight' : 'normal',
'size'   : 12,
        }

legend = plt.legend(handles = [A,B,C,D,E,F],frameon=False, prop = font1) #显示图例
plt.xlabel('Ply angle / $^\circ$',fontproperties = 'arial',size = 14)
plt.ylabel('radius / mm',fontproperties = 'arial',size = 14)
plt.xticks(fontproperties = 'arial', size = 14)
plt.yticks(fontproperties = 'arial', size = 14)
#plt.savefig('radius-ply angle.tif',dpi = 300,bbox_inches = 'tight',pad_inches = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

myfont = FontProperties(fname = 'C:/Windows/Fonts/times.ttf' )
 
t1 = 0.523
t2 = 0.6105
t3 = 0.6978
t4 = 0.785
t5 = 0.8722
t6 = 0.9594
#x = 0.9594
R= np.arange(18,28,2)
y1 = R*(57.5+61.15*np.cos(2*t1)+13.98*np.cos(4*t1))/(16.57-13.98*np.cos(4*t1))
y2 = R*(57.5+61.15*np.cos(2*t2)+13.98*np.cos(4*t2))/(16.57-13.98*np.cos(4*t2))
y3 = R*(57.5+61.15*np.cos(2*t3)+13.98*np.cos(4*t3))/(16.57-13.98*np.cos(4*t3))
y4 = R*(57.5+61.15*np.cos(2*t4)+13.98*np.cos(4*t4))/(16.57-13.98*np.cos(4*t4))
y5 = R*(57.5+61.15*np.cos(2*t5)+13.98*np.cos(4*t5))/(16.57-13.98*np.cos(4*t5))
y6 = R*(57.5+61.15*np.cos(2*t6)+13.98*np.cos(4*t6))/(16.57-13.98*np.cos(4*t6))
#y7 = 28*(57.5+61.15*np.cos(2*x)+13.98*np.cos(4*x))/(16.57-13.98*np.cos(4*x))

A, = plt.plot(R,y1,c = 'darkblue', ls = '--',lw = 2,label = 'ply angle = 30$^\circ$')
B, = plt.plot(R,y2,c = 'mediumblue', ls = '-',lw = 2,label = 'ply angle = 35$^\circ$')
C, = plt.plot(R,y3,c = 'blue', ls = '-.',lw = 2,label = 'ply angle = 40$^\circ$')
D, = plt.plot(R,y4,c = 'royalblue', ls = '-',lw = 2,label = 'ply angle = 45$^\circ$')
E, = plt.plot(R,y5,c = 'cornflowerblue', ls = ':',lw = 2,label = 'ply angle = 50$^\circ$')
F, = plt.plot(R,y6,c = 'lightsteelblue', ls = '--',lw = 2,label = 'ply angle = 55$^\circ$')
#plt.scatter(x,y7,c='orangered', s=50,marker='*', alpha=1, label = 'Minima')

font1 = {'family' : 'arial',
'weight' : 'normal',
'size'   : 12,
        }

legend = plt.legend(handles = [A,B,C,D,E,F],frameon=True, prop = font1,loc = 'upper left') #显示图例
plt.xlabel('Initial radius / mm',fontproperties = 'arial',size = 14)
plt.ylabel('Radius / mm',fontproperties = myfont,size = 14)
plt.xticks(fontproperties = 'arial', size = 14)
plt.yticks(fontproperties = 'arial', size = 14)
plt.savefig('radius-radius.tif',dpi = 300,bbox_inches = 'tight',pad_inches = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

myfont = FontProperties(fname = 'C:/Windows/Fonts/times.ttf' )
 
#t = np.arange(0.174,1.5708,0.01)
E1=np.arange(0,25,1)
t = 0.785

y1 = 18*(-2.*np.cos(2*t)**2*E1**2+41.7*np.cos(2*t)**2*E1-33.475*np.cos(2*t)**2-4.*E1**2*np.cos(2*t)+41.2*E1*np.cos(2*t)-2.*E1**2-82.9*E1+33.475)/(-E1**2+.25*E1-16.7375+np.cos(4*t)*E1**2-20.85*np.cos(4*t)*E1+16.7375*np.cos(4*t))
y2 = 20*(-2.*np.cos(2*t)**2*E1**2+41.7*np.cos(2*t)**2*E1-33.475*np.cos(2*t)**2-4.*E1**2*np.cos(2*t)+41.2*E1*np.cos(2*t)-2.*E1**2-82.9*E1+33.475)/(-E1**2+.25*E1-16.7375+np.cos(4*t)*E1**2-20.85*np.cos(4*t)*E1+16.7375*np.cos(4*t))
y3 = 22*(-2.*np.cos(2*t)**2*E1**2+41.7*np.cos(2*t)**2*E1-33.475*np.cos(2*t)**2-4.*E1**2*np.cos(2*t)+41.2*E1*np.cos(2*t)-2.*E1**2-82.9*E1+33.475)/(-E1**2+.25*E1-16.7375+np.cos(4*t)*E1**2-20.85*np.cos(4*t)*E1+16.7375*np.cos(4*t))
y4 = 24*(-2.*np.cos(2*t)**2*E1**2+41.7*np.cos(2*t)**2*E1-33.475*np.cos(2*t)**2-4.*E1**2*np.cos(2*t)+41.2*E1*np.cos(2*t)-2.*E1**2-82.9*E1+33.475)/(-E1**2+.25*E1-16.7375+np.cos(4*t)*E1**2-20.85*np.cos(4*t)*E1+16.7375*np.cos(4*t))
y5 = 26*(-2.*np.cos(2*t)**2*E1**2+41.7*np.cos(2*t)**2*E1-33.475*np.cos(2*t)**2-4.*E1**2*np.cos(2*t)+41.2*E1*np.cos(2*t)-2.*E1**2-82.9*E1+33.475)/(-E1**2+.25*E1-16.7375+np.cos(4*t)*E1**2-20.85*np.cos(4*t)*E1+16.7375*np.cos(4*t))
y6 = 28*(-2.*np.cos(2*t)**2*E1**2+41.7*np.cos(2*t)**2*E1-33.475*np.cos(2*t)**2-4.*E1**2*np.cos(2*t)+41.2*E1*np.cos(2*t)-2.*E1**2-82.9*E1+33.475)/(-E1**2+.25*E1-16.7375+np.cos(4*t)*E1**2-20.85*np.cos(4*t)*E1+16.7375*np.cos(4*t))
#y7 = 28*(57.5+61.15*np.cos(2*x)+13.98*np.cos(4*x))/(16.57-13.98*np.cos(4*x))

plt.plot(E1,y1,c = 'darkblue', ls = '--',lw = 2,label = 'R = 18mm')
plt.plot(E1,y2,c = 'mediumblue', ls = '-',lw = 2,label = 'R = 20mm')
plt.plot(E1,y3,c = 'blue', ls = '-.',lw = 2,label = 'R = 22mm')
plt.plot(E1,y4,c = 'royalblue', ls = '-',lw = 2,label = 'R = 24mm')
plt.plot(E1,y5,c = 'cornflowerblue', ls = ':',lw = 2,label = 'R = 26mm')
plt.plot(E1,y6,c = 'lightsteelblue', ls = '--',lw = 2,label = 'R = 28mm')
#plt.scatter(x,y7,c='orangered', s=50,marker='*', alpha=1, label = 'Minima')

plt.legend() #显示图例
plt.xlabel('E1 / GPa',fontproperties = myfont)
plt.ylabel('radius / mm',fontproperties = myfont)
plt.savefig('radius-E1-1.tif',dpi = 300,bbox_inches = 'tight',pad_inches = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
 
#t = np.arange(0.174,1.5708,0.01)
E2=np.arange(0.0,1000.0,1)


y1 = 18*(39.+.371875*E2)/(26.+.378125*E2)
y2 = 20*(39.+.371875*E2)/(26.+.378125*E2)
y3 = 22*(39.+.371875*E2)/(26.+.378125*E2)
y4 = 24*(39.+.371875*E2)/(26.+.378125*E2)
y5 = 26*(39.+.371875*E2)/(26.+.378125*E2)
y6 = 28*(39.+.371875*E2)/(26.+.378125*E2)
# #y7 = 28*(57.5+61.15*np.cos(2*x)+13.98*np.cos(4*x))/(16.57-13.98*np.cos(4*x))

A, = plt.plot(E2,y1,c = 'darkblue', ls = '--',lw = 2,label = 'R = 18mm')
B, = plt.plot(E2,y2,c = 'mediumblue', ls = '-',lw = 2,label = 'R = 20mm')
C, = plt.plot(E2,y3,c = 'blue', ls = '-.',lw = 2,label = 'R = 22mm')
D, = plt.plot(E2,y4,c = 'royalblue', ls = '-',lw = 2,label = 'R = 24mm')
E, = plt.plot(E2,y5,c = 'cornflowerblue', ls = ':',lw = 2,label = 'R = 26mm')
F, = plt.plot(E2,y6,c = 'lightsteelblue', ls = '--',lw = 2,label = 'R = 28mm')
#plt.scatter(x,y7,c='orangered', s=50,marker='*', alpha=1, label = 'Minima')

font1 = {'family' : 'arial',
'weight' : 'normal',
'size'   : 12,
        }

legend = plt.legend(handles = [A,B,C,D,E,F],frameon=False, prop = font1) #显示图例
plt.xlabel('$E_2$ / GPa',fontproperties = 'arial',size = 14)
plt.ylabel('Radius / mm',fontproperties = myfont,size = 14)
plt.xticks(fontproperties = 'arial', size = 14)
plt.yticks(fontproperties = 'arial', size = 14)
plt.savefig('radius-E2.tif',dpi = 300,bbox_inches = 'tight',pad_inches = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

myfont = FontProperties(fname = 'C:/Windows/Fonts/times.ttf' )
 
#t = np.arange(0.174,1.5708,0.01)
E1=np.arange(25,1000,1)
t = 0.785

y1 = 18.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y2 = 20.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y3 = 22.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y4 = 24.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y5 = 26.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y6 = 28.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
# #y7 = 28*(57.5+61.15*np.cos(2*x)+13.98*np.cos(4*x))/(16.57-13.98*np.cos(4*x))

plt.plot(E1,y1,c = 'darkblue', ls = '--',lw = 2,label = 'R = 18mm')
plt.plot(E1,y2,c = 'mediumblue', ls = '-',lw = 2,label = 'R = 20mm')
plt.plot(E1,y3,c = 'blue', ls = '-.',lw = 2,label = 'R = 22mm')
plt.plot(E1,y4,c = 'royalblue', ls = '-',lw = 2,label = 'R = 24mm')
plt.plot(E1,y5,c = 'cornflowerblue', ls = ':',lw = 2,label = 'R = 26mm')
plt.plot(E1,y6,c = 'lightsteelblue', ls = '--',lw = 2,label = 'R = 28mm')
#plt.scatter(x,y7,c='orangered', s=50,marker='*', alpha=1, label = 'Minima')

plt.legend() #显示图例
plt.xlabel('E1 / GPa',fontproperties = myfont)
plt.ylabel('radius / mm',fontproperties = myfont)
#plt.savefig('radius-E1-2.tif',dpi = 300,bbox_inches = 'tight',pad_inches = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

myfont = FontProperties(fname = 'C:/Windows/Fonts/times.ttf' )
 
#diyigetu
E1=np.arange(0.0,25.0,1)

y11 = 18.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y21 = 20.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y31 = 22.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y41 = 24.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y51 = 26.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y61 = 28.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)

plt.subplot(1,2,1)
plt.plot(E1,y11,c = 'darkblue', ls = '--',lw = 2,label = 'R = 18mm')
plt.plot(E1,y21,c = 'mediumblue', ls = '-',lw = 2,label = 'R = 20mm')
plt.plot(E1,y31,c = 'blue', ls = '-.',lw = 2,label = 'R = 22mm')
plt.plot(E1,y41,c = 'royalblue', ls = '-',lw = 2,label = 'R = 24mm')
plt.plot(E1,y51,c = 'cornflowerblue', ls = ':',lw = 2,label = 'R = 26mm')
plt.plot(E1,y61,c = 'lightsteelblue', ls = '--',lw = 2,label = 'R = 28mm')
plt.legend() #显示图例
plt.xlabel('E1 / GPa',fontproperties = myfont)
plt.ylabel('radius / mm',fontproperties = myfont)

###diergetu

E1=np.arange(25,1000,1)


y12 = 18.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y22 = 20.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y32 = 22.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y42 = 24.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y52 = 26.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y62 = 28.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)

plt.subplot(1,2,2)
plt.plot(E1,y12,c = 'darkblue', ls = '--',lw = 2,label = 'R = 18mm')
plt.plot(E1,y22,c = 'mediumblue', ls = '-',lw = 2,label = 'R = 20mm')
plt.plot(E1,y32,c = 'blue', ls = '-.',lw = 2,label = 'R = 22mm')
plt.plot(E1,y42,c = 'royalblue', ls = '-',lw = 2,label = 'R = 24mm')
plt.plot(E1,y52,c = 'cornflowerblue', ls = ':',lw = 2,label = 'R = 26mm')
plt.plot(E1,y62,c = 'lightsteelblue', ls = '--',lw = 2,label = 'R = 28mm')


plt.legend() #显示图例
plt.xlabel('E1 / GPa',fontproperties = myfont)
plt.ylabel('radius / mm',fontproperties = myfont)
#plt.savefig('radius-E1-2.tif',dpi = 300,bbox_inches = 'tight',pad_inches = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
# from matplotlib import rcParams

# rcParams['font.family'] = 'serif'
# myfont = FontProperties(fname = 'C:/Windows/Fonts/times.ttf' )

fig = plt.figure() 
#t = np.arange(0.174,1.5708,0.01)
E1=np.arange(25,1000,1)

ax1 = fig.add_axes([0.1,0.1,1.0,1.0])
y1 = 18.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y2 = 20.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y3 = 22.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y4 = 24.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y5 = 26.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y6 = 28.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)

ax1.plot(E1,y1,c = 'darkblue', ls = '--',lw = 2,label = 'R = 18mm')
ax1.plot(E1,y2,c = 'mediumblue', ls = '-',lw = 2,label = 'R = 20mm')
ax1.plot(E1,y3,c = 'blue', ls = '-.',lw = 2,label = 'R = 22mm')
ax1.plot(E1,y4,c = 'royalblue', ls = '-',lw = 2,label = 'R = 24mm')
ax1.plot(E1,y5,c = 'cornflowerblue', ls = ':',lw = 2,label = 'R = 26mm')
ax1.plot(E1,y6,c = 'lightsteelblue', ls = '--',lw = 2,label = 'R = 28mm')

font1 = {'family' : 'arial',
'weight' : 'normal',
'size'   : 12,
        }

#legend = plt.legend(handles = [A,B,C,D,E,F],frameon=False, prop = font1) #显示图例

plt.legend(frameon=False, prop = font1) #显示图例
ax1.set_xlabel(r'$E_1$ / GPa', fontdict={'family' : 'arial', 'size'   : 16})
ax1.set_ylabel('Radius / mm', fontdict={'family' : 'arial', 'size'   : 16})
plt.xticks(fontproperties = 'arial', size = 14)
plt.yticks(fontproperties = 'arial', size = 14)


E1=np.arange(0.0,25.0,1)
ax2 = fig.add_axes([0.35,0.5,0.5,0.5])
y1 = 18.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y2 = 20.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y3 = 22.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y4 = 24.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y5 = 26.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)
y6 = 28.0*(E1**2+41.45*E1-16.7375)/(E1**2-10.55*E1+16.7375)

ax2.plot(E1,y1,c = 'darkblue', ls = '--',lw = 2,label = 'R = 18mm')
ax2.plot(E1,y2,c = 'mediumblue', ls = '-',lw = 2,label = 'R = 20mm')
ax2.plot(E1,y3,c = 'blue', ls = '-.',lw = 2,label = 'R = 22mm')
ax2.plot(E1,y4,c = 'royalblue', ls = '-',lw = 2,label = 'R = 24mm')
ax2.plot(E1,y5,c = 'cornflowerblue', ls = ':',lw = 2,label = 'R = 26mm')
ax2.plot(E1,y6,c = 'lightsteelblue', ls = '--',lw = 2,label = 'R = 28mm')
plt.xticks(fontproperties = 'arial', size = 14)
plt.yticks(fontproperties = 'arial', size = 14)

#plt.legend() #显示图例
# ax2.set_xlabel('E1 / GPa',fontproperties = myfont)
# ax2.set_ylabel('radius / mm',fontproperties = myfont)


plt.savefig('radius-E1-E1.tif',dpi = 300,bbox_inches = 'tight',pad_inches = 0.5)
plt.show()
