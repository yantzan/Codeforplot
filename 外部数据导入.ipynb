# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('C:/Users/12/Desktop/ts.txt')
print(data)
# Out:
# [[  0.00000000e+00   0.00000000e+00]
#  [  2.00005000e-02   4.45638000e+00]
#  [  4.00020000e-02   3.38219000e+01]
#  [  6.00020000e-02   1.12297000e+02]
#  [  8.00007000e-02   2.63486000e+02]
#  [  1.00003000e-01   5.10150000e+02]
#  [  1.20000000e-01   8.74238000e+02]
#  [  1.40002000e-01   1.37664000e+03]
#  [  1.60004000e-01   2.03817000e+03]
#  [  1.80002000e-01   2.87842000e+03]
#  [  2.00005000e-01   3.91693000e+03]
#  [  2.20002000e-01   5.17103000e+03]
#  [  2.40005000e-01   6.65792000e+03]
#  [  2.60002000e-01   8.39164000e+03]
#  [  2.80004000e-01   1.03854000e+04]
#  [  3.00000000e-01   1.26169000e+04]
#  [  3.20002000e-01   1.41120000e+04]
#  [  3.40004000e-01   1.69795000e+04]
#  [  3.60000000e-01   1.93095000e+04]
#  [  3.80002000e-01   2.00859000e+04]
#  [  4.00004000e-01   2.76436000e+03]
#  [  4.20000000e-01   3.65248000e+03]
#  [  4.40002000e-01   6.17271000e+03]
#  [  4.60004000e-01   1.73995000e+03]
#  [  4.80000000e-01   3.28737000e+03]
# ...

# %%
x = data[:,0]
y = data[:,1]
plt.plot(x,y)
plt.show()

# %%
import xlrd
import numpy as np
import matplotlib.pyplot as plt

book = xlrd.open_workbook("C:/Users/12/Desktop/hengjiemian.xlsx")#打开Excel文件
sheetName = book.sheet_names() #取Excel文件的所有工作表，即sheet（i）
sheet1 = book.sheet_by_name(sheetName[0])#将第一个工作表取出来
data_col0 = sheet1.col_values(0)[0:402]#取工作表1中的第一列数据，为时间
data_col1 = sheet1.col_values(1)[0:402]#去工作表中的第三列数据，为能量
x = data_col0 #将第一列数据赋给x
y = data_col1#将第一列数据赋给y
plt.plot(x,y)#绘图
plt.show()
